# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("airline_passenger_satisfaction.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %% [markdown]
# ### 1. Which percentage of airline passengers are satisfied? Does it vary by customer type? What about type of travel?

# %%
round(df["Satisfaction"].value_counts(normalize = True)*100)
# Out:
# Neutral or Dissatisfied    57.0
# Satisfied                  43.0
# Name: Satisfaction, dtype: float64

# %% [markdown]
# #### About 43% passengers are sataisfied

# %%
sns.catplot(x = "Customer Type", data = df,kind = "count", hue = "Satisfaction")
plt.xticks(rotation = 45)
# Out:
# (array([0, 1]), [Text(0, 0, 'First-time'), Text(1, 0, 'Returning')])

# %%
round(df.groupby("Customer Type")["Satisfaction"].value_counts(normalize = True)*100)
# Out:
# Customer Type  Satisfaction
# First-time     Neutral or Dissatisfied    76.0
#                Satisfied                  24.0
# Returning      Neutral or Dissatisfied    52.0
#                Satisfied                  48.0
# Name: Satisfaction, dtype: float64

# %%
df["Customer Type"].value_counts()
# Out:
# Returning     106100
# First-time     23780
# Name: Customer Type, dtype: int64

# %%
sns.catplot(x = "Satisfaction", data = df,kind = "count", hue = "Customer Type")
plt.xticks(rotation = 45)
# Out:
# (array([0, 1]),
#  [Text(0, 0, 'Neutral or Dissatisfied'), Text(1, 0, 'Satisfied')])

# %% [markdown]
# #### Yes Customer satisfaction vary by Customer type
#  Only 24% of First Time Customers are satisfied and 48% of Returning Customers are satisfied.

# %%
round(df.groupby("Type of Travel")["Satisfaction"].value_counts(normalize = True)*100)
# Out:
# Type of Travel  Satisfaction
# Business        Satisfied                  58.0
#                 Neutral or Dissatisfied    42.0
# Personal        Neutral or Dissatisfied    90.0
#                 Satisfied                  10.0
# Name: Satisfaction, dtype: float64

# %%
col_palette= {"Satisfied": "Green", "Neutral or Dissatisfied": "Red"}
sns.catplot(x = "Type of Travel", data = df,kind = "count",col = "Customer Type", hue = "Satisfaction", palette = col_palette, alpha = 0.7)
plt.xticks(rotation = 45)
# Out:
# (array([0, 1]), [Text(0, 0, 'Business'), Text(1, 0, 'Personal')])

# %%
col_palette= {"Satisfied": "Green", "Neutral or Dissatisfied": "Red"}
sns.catplot(x = "Customer Type", data = df,kind = "count",col = "Type of Travel", hue = "Satisfaction", palette = col_palette, alpha = 0.5)
plt.xticks(rotation = 45)
# Out:
# (array([0, 1]), [Text(0, 0, 'First-time'), Text(1, 0, 'Returning')])

# %%
df.groupby(["Type of Travel","Customer Type"])["Satisfaction"].value_counts()
# Out:
# Type of Travel  Customer Type  Satisfaction
# Business        First-time     Neutral or Dissatisfied    17911
#                                Satisfied                   5668
#                 Returning      Satisfied                  46688
#                                Neutral or Dissatisfied    19426
# Personal        First-time     Neutral or Dissatisfied      169
#                                Satisfied                     32
#                 Returning      Neutral or Dissatisfied    35946
#                                Satisfied                   4040
# Name: Satisfaction, dtype: int64

# %%
round(df.groupby(["Type of Travel","Customer Type"])["Satisfaction"].value_counts(normalize = True)*100)
# Out:
# Type of Travel  Customer Type  Satisfaction
# Business        First-time     Neutral or Dissatisfied    76.0
#                                Satisfied                  24.0
#                 Returning      Satisfied                  71.0
#                                Neutral or Dissatisfied    29.0
# Personal        First-time     Neutral or Dissatisfied    84.0
#                                Satisfied                  16.0
#                 Returning      Neutral or Dissatisfied    90.0
#                                Satisfied                  10.0
# Name: Satisfaction, dtype: float64

# %% [markdown]
# ### What is the customer profile for a repeating airline passenger?

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Gender', 'Age', 'Customer Type', 'Type of Travel', 'Class',
#        'Flight Distance', 'Departure Delay', 'Arrival Delay',
#        'Departure and Arrival Time Convenience', 'Ease of Online Booking',
#        'Check-in Service', 'Online Boarding', 'Gate Location',
#        'On-board Service', 'Seat Comfort', 'Leg Room Service', 'Cleanliness',
#        'Food and Drink', 'In-flight Service', 'In-flight Wifi Service',
#        'In-flight Entertainment', 'Baggage Handling', 'Satisfaction'],
#       dtype='object')

# %%
returning_df = df[df["Customer Type"] == "Returning"]

# %%
returning_df.groupby("Gender")["Age"].agg([min, max, np.mean , np.median, pd.Series.mode])
# Out:
#         min  max       mean  median  mode
# Gender
# Female    7   85  41.437048    43.0    39
# Male      7   85  41.486973    43.0    39

# %%
sns.set_theme(style="whitegrid")
# white, whitegrid, ticks, darkgrid
sns.displot(returning_df, x="Age", col="Gender", hue = "Gender")

# %% [markdown]
# ### Does flight distance affect customer preferences or flight patterns?

# %%
df["Class"].value_counts()
# Out:
# Business        62160
# Economy         58309
# Economy Plus     9411
# Name: Class, dtype: int64

# %%
df.iloc[:, 6:23 ]
# Out:
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# 1                   821               26           39.0
# 2                   853                0            0.0
# 3                  1905                0            0.0
# 4                  3470                0            1.0
# ...                 ...              ...            ...
# 129875              447                2            3.0
# 129876              308                0            0.0
# 129877              337                6           14.0
# 129878              337               31           22.0
# 129879              337                0            0.0
#
#         Departure and Arrival Time Convenience  Ease of Online Booking  \
# 0                                            3                       3
# 1                                            2                       2
# 2                                            4                       4
# ...

# %%
sns.set_context("paper")
# paper, notebook, talk, poster
sns.displot(df, x="Flight Distance", hue = "Class", kind = "kde" )

# %% [markdown]
# ### Which factors contribute to customer satisfaction the most? What about dissatisfaction?

# %%
list = ['Flight Distance', 'Departure Delay', 'Arrival Delay',
       'Departure and Arrival Time Convenience', 'Ease of Online Booking',
       'Check-in Service', 'Online Boarding', 'Gate Location',
       'On-board Service', 'Seat Comfort', 'Leg Room Service', 'Cleanliness',
       'Food and Drink', 'In-flight Service', 'In-flight Wifi Service',
       'In-flight Entertainment', 'Baggage Handling']
for i in list:
 sns.displot(df, x= df[i] , hue = "Satisfaction", kind = "kde")

# %% [markdown]
# sns.heatmap(df.corr(), cmap='YlGnBu')

# %% [markdown]
# df.corr().style.background_gradient()
